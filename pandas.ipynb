# %% [markdown]
# padas

# %%
print('hello world')
# Out:
# hello world

# %%
import pandas as pd
import requests

# %%
df=pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
df1=df[0]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rk      675 non-null    object
#  1   Player  675 non-null    object
#  2   Pos     675 non-null    object
#  3   Age     675 non-null    object
#  4   Tm      675 non-null    object
#  5   G       675 non-null    object
#  6   GS      675 non-null    object
#  7   MP      675 non-null    object
#  8   FG      675 non-null    object
#  9   FGA     675 non-null    object
#  10  FG%     673 non-null    object
#  11  3P      675 non-null    object
#  12  3PA     675 non-null    object
#  13  3P%     594 non-null    object
#  14  2P      675 non-null    object
#  15  2PA     675 non-null    object
#  16  2P%     671 non-null    object
#  17  eFG%    673 non-null    object
#  18  FT      675 non-null    object
#  19  FTA     675 non-null    object
#  20  FT%     650 non-null    object
# ...

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.isnull().sum()
# Out:
# Rk         0
# Player     0
# Pos        0
# Age        0
# Tm         0
# G          0
# GS         0
# MP         0
# FG         0
# FGA        0
# FG%        2
# 3P         0
# 3PA        0
# 3P%       81
# 2P         0
# 2PA        0
# 2P%        4
# eFG%       2
# FT         0
# FTA        0
# FT%       25
# ORB        0
# DRB        0
# TRB        0
# AST        0
# STL        0
# BLK        0
# TOV        0
# PF         0
# PTS        0
# dtype: int64

# %%
import missingno as msno

# %%
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df1
#
# NameError: name 'df1' is not defined

# %%
msno.bar(df1,color='orange')
# Out:
# <Axes: >

# %%
df1['Rk']
# Out:
# 0        1.0
# 1        2.0
# 2        3.0
# 3        4.0
# 4        5.0
#        ...
# 670    490.0
# 671    490.0
# 672    490.0
# 673    491.0
# 674    492.0
# Name: Rk, Length: 675, dtype: float64

# %%
change_dtype=['Rk',  'Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
       '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
       'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']

for i in change_dtype:
       df1[i] = pd.to_numeric(df1[i],errors='coerce')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rk      651 non-null    float64
#  1   Player  675 non-null    object
#  2   Pos     675 non-null    object
#  3   Age     651 non-null    float64
#  4   Tm      675 non-null    object
#  5   G       651 non-null    float64
#  6   GS      651 non-null    float64
#  7   MP      651 non-null    float64
#  8   FG      651 non-null    float64
#  9   FGA     651 non-null    float64
#  10  FG%     649 non-null    float64
#  11  3P      651 non-null    float64
#  12  3PA     651 non-null    float64
#  13  3P%     570 non-null    float64
#  14  2P      651 non-null    float64
#  15  2PA     651 non-null    float64
#  16  2P%     647 non-null    float64
#  17  eFG%    649 non-null    float64
#  18  FT      651 non-null    float64
#  19  FTA     651 non-null    float64
# ...

# %%
df1.describe()
# Out:
#                Rk         Age           G          GS           MP  \
# count  651.000000  651.000000  651.000000  651.000000   651.000000
# mean   256.251920   26.500768   45.960061   21.099846  1041.775730
# std    143.170456    4.110914   25.503151   25.932412   806.253103
# min      1.000000   19.000000    1.000000    0.000000     1.000000
# 25%    130.500000   23.000000   24.000000    0.000000   272.000000
# 50%    262.000000   26.000000   48.000000    9.000000   896.000000
# 75%    381.500000   29.000000   70.000000   35.000000  1674.000000
# max    492.000000   38.000000   83.000000   82.000000  2981.000000
#
#                FG          FGA         FG%          3P         3PA  ...  \
# count  651.000000   651.000000  649.000000  651.000000  651.000000  ...
# mean   160.778802   359.763441    0.427404   33.917051   97.419355  ...
# std    148.971531   322.834979    0.100285   44.168306  118.003315  ...
# min      0.000000     0.000000    0.000000    0.000000    0.000000  ...
# ...

# %%
pip install bs4
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1264 sha256=21f811ea952b223dd4b9ab2f05effd6ae72d0f00ac32c426cf5a79662a380ec5
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\d4\c8\5b\b5be9c20e5e4503d04a6eac8a3cd5c2393505c29f02bea0960
# Successfully built bs4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
url='https://www.amazon.in/s?hidden-keywords=B0B3RRWSF6+%7C+B0B5B6PQCT+%7C+B0BF57RN3K+%7C+B0B6BLTGTT+%7C+B0B854R7NS+%7C+B0B5LVS732+%7C+B0BJ72WZQ7+%7C+B09NVPSCQT+%7C+B0B53QFZPY+%7C+B0B3RSDSZ3+%7C+B0B5DDJNH4+%7C+B0BP18W8TM+%7C+B0BF563HB4+%7C+B09V12K8NT+%7C+B09YV4MW2T+%7C+B0B5LW5DFQ+%7C+B0B6BPX5S9+%7C+B09YV42QHZ+%7C+B0B5LWP12T+%7C+B0BF4YBLPX+%7C+B0BRJF98R9+%7C+B0B53NXFFR+%7C+B09RK7XWQS+%7C+B0BBVKRP7B+%7C+B0BMM4MBT2&_encoding=UTF8&content-id=amzn1.sym.431315b1-a020-46ac-b0de-57aa06376fcd&pd_rd_r=62a1fd06-198b-41e1-adda-c8cae63da181&pd_rd_w=bzGPC&pd_rd_wg=1xaa4&pf_rd_p=431315b1-a020-46ac-b0de-57aa06376fcd&pf_rd_r=ENS24WRDY2XZ4KE0ETB8&ref=pd_gw_unk'

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
HEADERS=({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36', 'Accept-Language':'en-US, en;q=0.5'})
    
    #add amazon url
URL = "https://www.amazon.com/s?k=playstation+4&ref=nb_sb_noss_2"
    
    #Http Request
R=requests.get(URL,headers=HEADERS)
    
    #Soup object to get data
soup=BeautifulSoup(R.content,"html.parser")

# %%
webpage
# Out:
# <Response [503]>
